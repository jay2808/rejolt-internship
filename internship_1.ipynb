# %%
import pandas as p
import numpy as np

# %%
d=p.read_csv("disney_movies.csv")
d.head
print(d.isnull())
# Out:
#      movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0          False         False  False        False        False
# 1          False         False  False        False        False
# 2          False         False  False        False        False
# 3          False         False  False        False        False
# 4          False         False  False        False        False
# ..           ...           ...    ...          ...          ...
# 574        False         False  False        False        False
# 575        False         False  False        False        False
# 576        False         False  False        False        False
# 577        False         False  False        False        False
# 578        False         False  False        False        False
#
#      inflation_adjusted_gross
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...

# %%
d.head(6)

# %%
d.sample(6)
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 531        Oz the Great and Powerful   2013-03-08  Adventure          PG
# 468                           WALL-E   2008-06-27  Adventure           G
# 322                          Gun Shy   2000-02-04     Comedy           R
# 122                      Passed Away   1992-04-24        NaN       PG-13
# 570  Alice Through the Looking Glass   2016-05-27  Adventure          PG
# 79                    Turner & Hooch   1989-07-28     Comedy          PG
#
#      total_gross  inflation_adjusted_gross
# 531    234770996                 243434130
# 468    223808164                 262771918
# 322      1638202                   2562155
# 122      4030793                   8187848
# 570     77042381                  77042381
# 79      71079915                 150176361

# %%
d.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
a=d.isnull()
a
# Out:
#      movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0          False         False  False        False        False
# 1          False         False  False        False        False
# 2          False         False  False        False        False
# 3          False         False  False        False        False
# 4          False         False  False        False        False
# ..           ...           ...    ...          ...          ...
# 574        False         False  False        False        False
# 575        False         False  False        False        False
# 576        False         False  False        False        False
# 577        False         False  False        False        False
# 578        False         False  False        False        False
#
#      inflation_adjusted_gross
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...

# %%
d.dropna()
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
# how many total missing values do we have?
total = np.product(d.shape)
t_missing= a.sum()

# percent of data that is missing
k=(t_missing/total) * 100
k
# Out:
# movie_title                 0.000000
# release_date                0.000000
# genre                       0.489349
# mpaa_rating                 1.611975
# total_gross                 0.000000
# inflation_adjusted_gross    0.000000
# dtype: float64

# %%
d.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_3.groupby('release_date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['release_date'].value_counts()
    for x_label, grp in _df_12.groupby('movie_title')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('movie_title')
_ = plt.ylabel('release_date')

# %%
from matplotlib import pyplot as plt
_df_0['total_gross'].plot(kind='hist', bins=20, title='total_gross')
plt.gca().spines[['top', 'right',]].set_visible(False)
